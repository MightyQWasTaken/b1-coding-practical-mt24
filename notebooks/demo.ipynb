# %%
# Add relevant Jupyter notebook extensions

# %%
# You can double-check your Python path like this...
import sys  
print(sys.path)
# Out:
# ['c:\\Users\\User\\Documents\\University\\Year 3\\B1 Engineering Computation\\Scientific Coding\\Project\\b1-coding-practical-mt24\\notebooks', 'c:\\Users\\User\\anaconda3\\python312.zip', 'c:\\Users\\User\\anaconda3\\DLLs', 'c:\\Users\\User\\anaconda3\\Lib', 'c:\\Users\\User\\anaconda3', '', 'c:\\Users\\User\\anaconda3\\Lib\\site-packages', 'c:\\Users\\User\\anaconda3\\Lib\\site-packages\\win32', 'c:\\Users\\User\\anaconda3\\Lib\\site-packages\\win32\\lib', 'c:\\Users\\User\\anaconda3\\Lib\\site-packages\\Pythonwin']

# %% [markdown]
# # Simulate closed-loop
# After implementing your control functionality, you can simulate the closed-loop with code that looks something like this...

# %%
import numpy as np
import os
sys.path.append(os.path.abspath('c:\\Users\\User\\Documents\\University\\Year 3\\B1 Engineering Computation\\Scientific Coding\\Project\\b1-coding-practical-mt24\\uuv_mission'))

from dynamic import *
from control import *
from terrain import *

#change gain of controller as needed
gain = float(0.02)

sub = Submarine()
# Instantiate your controller (depending on your implementation) || AKA do something about controller here!!
closed_loop = ClosedLoop(sub)

mission = Mission()
mission.from_csv("c:\\Users\\User\\Documents\\University\\Year 3\\B1 Engineering Computation\\Scientific Coding\\Project\\b1-coding-practical-mt24\\data\\mission.csv")

trajectory = closed_loop.simulate_with_random_disturbances(mission, gain)
trajectory.plot_completed_mission(mission)
